# %%
student = {}

student = {'backpack_empty':False}


print(student['backpack_empty'])
student['backpack'] = True
print(student['backpack'])
student['GPA'] = 3.8
# Out:
# False
# True

# %%
print(student)

for tempvalue in student.items():
    print("\nKey:" + tempvalue[0])
    print("Value:" + str(tempvalue[1]))
# Out:
# {'backpack_empty': False, 'backpack': True, 'GPA': 3.8}
#
# Key:backpack_empty
# Value:False
#
# Key:backpack
# Value:True
#
# Key:GPA
# Value:3.8

# %%
for value in student.keys():
    print("\nKey: " + value)
# Out:
# Key: backpack_empty
#
# Key: backpack
#
# Key: GPA

# %%
favorite_languages = {
    'Dad': 'python',
    'Mom': 'French',
    'Sister': 'English',
    'Wife': 'Spanish',
}

temp = {}
temp["favorite_languages"] = favorite_languages 
print(temp)

print(temp['favorite_languages'])
for key, value in temp['favorite_languages'].items(): 
    print("\nKey:" + key)
    print("Value:"+ value)
# Out:
# {'favorite_languages': {'Dad': 'python', 'Mom': 'French', 'Sister': 'English', 'Wife': 'Spanish'}}
# {'Dad': 'python', 'Mom': 'French', 'Sister': 'English', 'Wife': 'Spanish'}
#
# Key:Dad
# Value:python
#
# Key:Mom
# Value:French
#
# Key:Sister
# Value:English
#
# Key:Wife
# Value:Spanish

# %%
student_list = []

for student_number in range(100): 
    new_student = {'id': student_number, 'grade': 'Senior', 'GPA': '3.8'}
    student_list.append(new_student)

    for student in student_list[:5]:
        print(student)
# Out:
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 0, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 1, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 2, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 3, 'grade': 'Senior', 'GPA': '3.8'}
# {'id': 4, 'grade': 'Senior', 'GPA': '3.8'}

# %%
for student in student_list[:5]:
    student['GPA'] = 2.0
    
for student in student_list[:5]:
    print(student)

print(student_list[:5])
# Out:
# {'id': 0, 'grade': 'Senior', 'GPA': 2.0}
# {'id': 1, 'grade': 'Senior', 'GPA': 2.0}
# {'id': 2, 'grade': 'Senior', 'GPA': 2.0}
# {'id': 3, 'grade': 'Senior', 'GPA': 2.0}
# {'id': 4, 'grade': 'Senior', 'GPA': 2.0}
# [{'id': 0, 'grade': 'Senior', 'GPA': 2.0}, {'id': 1, 'grade': 'Senior', 'GPA': 2.0}, {'id': 2, 'grade': 'Senior', 'GPA': 2.0}, {'id': 3, 'grade': 'Senior', 'GPA': 2.0}, {'id': 4, 'grade': 'Senior', 'GPA': 2.0}]
